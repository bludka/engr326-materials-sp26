# %% [markdown]
# # ENGR 326 Lab 2: Euler's Method & Calculating Errors

# %% [markdown]
# # 1. Walking the stairs blindfolded
#
# In this lab you will develop a simple ODE solving technique called "Euler's Method". **Don't look it up yet**. Let's discover it through intuition and the guidance of this lab.

# %% [markdown]
# ## Question 1.1
# Imagine you are walking down the stairs but you suddenly blindfolded in the middle of the staircase. How would you estimate where to put your foot when you take your next step? (Imagine that you don't have a cane or other aids)
#
# *Double click on this box and write an answer using words here*

# %% [markdown]
# <img src="stairs.jpg">

# %% [markdown]
# ## Question 1.2
#
# Transform your previous answer (that you provided in words above) into a math equation using the following definitions:
#
# $y_i$ = the current elevation of your foot on the stairs
#
# $h$ = the width of the step you are about to take
#
# $\frac{dy}{dx}$ = slope of the stairs
#
# $y_{i+1}$ = the elevation of the location where you think you should put your foot next
#
# *Double click on this box and write your answer using math.*
#
# *Use "LaTeX formatting" to write your answer. You can see an example of this type of formatting in this box, where text is surrounded by dollar signs*.
#
# *Write your answer here*
#
# HINT: Your equation should be solving for $y_{i+1}$.

# %% [markdown]
# ## Question 1.3
#
# Run the code below to make a plot that shows the stairs in blue. We have also plotted the starting location of your foot as a red dot, and we have included a black dashed line that has the same slope as the stairs.
#
# **Using the formula you wrote above**, calculate the *next* location of your foot **using Python** (where it says YOUR CODE HERE) and add it to the plot below as another red dot.
#
# Peform the task using the following values (which are also provided in the code below):
#
# $x_0$ = 1.5 ft
#
# $y_0$ = 5 ft
#
# $h$= 1 ft
#
# $\frac{dy}{dx}$ = -5/8

# %%
import matplotlib.pyplot as plt
import numpy as np

x_0 = 1.5
y_0 = 5
h = 1
dydx = -5/8

#plot stairs
edges = np.arange(1, 11)
values = np.linspace(y_0, 0, 9)
plt.stairs(values, edges, fill=True, alpha=0.5, label = 'stairs')

#plot line with same slope as stairs
x_line = edges[1:]-0.5
y_line = values
plt.plot(x_line, y_line, 'k--', linewidth=2, label='stair slope')

#plot starting location
plt.plot(x_0,y_0,'ro',label='foot location') 

# YOUR CODE HERE
#calculate the next location of your foot by finding x_{i+1} and y_{i+1}
#plot the next location of your foot as a red dot

plt.xlabel('x distance [ft]')
plt.ylabel('y elevation [ft]')
plt.grid(True)
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# ## Question 1.4
#
# Using a **for loop** and **your equation** for your foot location, calculate the location of your foot on each of the seven stair-steps using Python, *where each foot location is calculated based on the previous foot location*. Then add red dots to each stair-step showing your foot locations.
#
# Perform these tasks in the code below where it says YOUR CODE HERE.
#
# Note that there are eight stair-steps and we have set n=8 in the code.

# %%
n = 8  #number of stair-steps
x_0 = 1.5
y_0 = 5
h = 1
dydx = -5/8

#plot stairs
edges = np.arange(1, 11)
values = np.linspace(y_0, 0, 9)
plt.stairs(values, edges, fill=True, alpha=0.5, label = 'stairs')

#plot line with same slope as stairs
x_line = edges[1:]-0.5
y_line = values
plt.plot(x_line, y_line, 'k--', linewidth=2, label = 'stair slope')

#plot starting location
plt.plot(x_0,y_0,'ro', label='foot location') 

# YOUR CODE HERE 
#1. Create a numpy array using np.arange() of your x foot locations on each stair-step, including the starting location.
    #Remember you can always use help(np.arange) to get more information on how to use the function.
#2. Create a storage array where you will store your y foot locations, but just fill it with zeros for now using np.zeros().
#     The storage array should have the same length as the number of stair-steps.
#3. Replace the first element in your y storage array with your starting y location. 
#4.Using a for-loop, calculate the location of your foot on each stair-step and store it in the array you just made.
#   !!To earn points: Each foot location must be calculated based on the previous foot location!!
#4. Plot the locations of your feet on each stair-step.

plt.xlabel('x distance [ft]')
plt.ylabel('y elevation [ft]')
plt.grid(True)
plt.axis('equal')
plt.legend()
plt.show()

# %% [markdown]
# # 2. First order decay
#
# Similar to the stair scenario, sometimes we have information about a solution's slope, but we don't know the value of the solution itself yet.
#
# For example:
#
# $$\frac{dy}{dt} = -ky$$
#
# This ODE represents how variables experiencing decay evolve over time. This is a useful equation to model pollution degredation in the environment, cooling or damping in mechanical systems, or battery discharge, among many other things!
#
# ## Question 2.1
#
# Don't solve the ODE above by hand yet. Instead **estimate the solution for y with Python using a similar method as you used for the stairs**. Then, plot your solution.
#
# HINT: The major difference between this scenario and the stair scenario is that the stair slope was constant, but here $\frac{dy}{dt}$ depends on y. Therefore you will need to calculate $\frac{dy}{dt}$ inside your for-loop using the ODE above.
#
# Assume:
#
# $k = 3$
#
# $t_0 = 0$ hrs
#
# $y_0 = 88$
#
# $h = .01$ hrs
#
# Run your model for $T=0.5$ hours.

# %%
k=3
t_0 = 0
y_0 = 88
h = .01
T = 0.5

# YOUR CODE HERE
#Create a numpy array using np.arange() of your time values.
#2. Create a storage array where you will store your y values, but just fill it with zeros for now using np.zeros().
#     The storage array should have the same length as your time array.
#3. Replace the first element in your y storage array with your initial y value. 
#4. Using a for-loop, estimate each y value and store it in the array you just made.
#   !!To earn points: Each y value must be calculated based on the previous y value!!
#   !!You will need to calculate dy/dx inside the for-loop using the ODE equation!!
#4. Plot the locations of your feet on each stair-step.

#Label your x axis
plt.xlabel('Time [hrs]')
#Choose your favorite y label. (Choose only 1. You can comment out or delete the others)
plt.ylabel('Concentration [mg/L]') 
plt.ylabel('Temperature [K]') 
plt.ylabel('Battery Charge [Amp-hours]') 
plt.grid(True) #turn on the grid

# %% [markdown]
# ## Question 2.2
#
# Now let's compare our numerical solution to the true solution.
#
# (It turns out that we can find a solution to this ODE by hand, but there are many ODEs where we won't be able to do that. We are starting with an ODE that we can solve by hand to help prepare us for situations where we won't have an analytical solution)
#
# Plot your solution on the same graph as the true solution. The true solution is
#
# $$y = Ce^{-kt}$$
#
# You will need to solve for C using your initial condition from the question above.

# %%
# YOUR CODE HERE
#Plot your numerical solution
#Plot your analytical solution in a different color
#Label your axes
#Include a legend in your plot where one curve is labeled "numerical" and the other is labeled "analytical"

# %% [markdown]
# # 3. Error metrics
#
# Now let's investigate the error of our solution compared to the true solution.
#
# ## Question 3.1
#
# Calculate and plot the **true error** at each time step.
#
# Time should be on the x axis, and true error should be on the y axis. Make sure to label your axes with both variable names and units.

# %%
# YOUR CODE HERE
# Calculate true error at each time step
# Plot true error at each time step
# Label your axes

# %% [markdown]
# ## Question 3.2
#
# Calculate and plot the **true percent relative error** at each time step. Make sure to label your axes appropriately.

# %%
# YOUR CODE HERE
# Calculate the true percent relative error at each time step
# Plot true percent relative error at each time step
# Label your axes

# %% [markdown]
# # 4. Adjusting step size
#
# The value we choose for our step-size $h$ can drastically impact our solution estimate.

# %% [markdown]
# ## Question 4.1
#
# Plot the following curves on the SAME plot:
#
# * Analytical (true) solution
# * Numerical solution using h = 0.1 hrs
# * Numerical solution using h = 0.01 hrs
# * Numerical solution using h = 0.001 hrs
#
# where time is on the x axis and the solution estimates are on the y axis.
#
# Label your axes appropriately and include a legend.

# %%
# YOUR CODE HERE
#Calculate the numerial solutions at each time step, using different values of h
#Plot the analytical and numerical solutions at each time step
#Label your axes
#Include a legend

# %% [markdown]
# ## Question 4.2
#
# Plot the true percent relative error for each of these solution estimates on the SAME plot:
#
# * Numerical solution using h = 0.1 hrs
# * Numerical solution using h = 0.01 hrs
# * Numerical solution using h = 0.001 hrs
#
# where time is on the x axis and true percent relative error is on the y axis.

# %%
# YOUR CODE HERE
#Calculate the true percent relative error for each numerical solution
#For each solution, plot the true percent relative error at each time step
#Label your axes
#Include a legend

# %% [markdown]
# ## Question 4.3
#
# Pretend instead, that we do not know the true error. Calculate and plot the **approximate relative percent error** at each time step using the $h=0.001$ numerical solution and the $h=0.01$ numerical solution.
#
# HINT: The two solutions you are comparing use different time values. To compare them, interpolate the fine-resolution solution onto the coarse time grid using `np.interp(t_coarse, t_fine, y_fine)`

# %%
# YOUR CODE HERE
# Calculate the solution using h=0.01
# Calculate the solution using h=0.001
# Calculate the approximate relative percent error at each time step
# Plot the approximate relative percent error at each time step
#Label your axes

# %% [markdown]
# ## Question 4.4
#
# Are the approximate and true relative errors for the $h=0.01$ solution in the last two questions similar?
#
# *Write your answer here.*
#
# NOTE: Approximate relative error closely tracks the true relative error when a method is converging and the solution is smooth. This will not always be the case.
#
# NOTE: Approximate error can also help us judge whether refining a calculation is still improving the result. This is especially useful when analytical solutions are not available.

# %% [markdown]
# ## Question 4.5
#
# Perform a "sensitivity analysis" on the solution at time t=0.5 hours by testing 100 different h values.
#
# The range of h should go from 0.0001 to 0.1
#
# Plot h on the x-axis and the percent relative error of the solution at t=0.5 on the y-axis.

# %%
# YOUR CODE HERE
# Calculate the numerical solution at 100 different h values
# While calculating, store the value of each numerical solution at t=0.5 hours
# Compare the value of the numerical solutions to the analytical solution at t=0.5 hours.
# Plot true percent relative error on the y axis, and h on the x axis.
# Label your axes

# %% [markdown]
# ## Question 4.6
#
# As $h$ gets smaller, does percent relative error increase or decrease?
#
# *Write your answer here*

# %% [markdown]
# IMPORTANT: In practice, decreasing the step size improves Euler's method only up to a point. In later examples, we will see why refinement has limits, including effects due to round-off error.

# %% [markdown]
# IMPORTANT: Smaller step sizes require more computational effort. In practice, we want to choose
# h small enough to achieve accuracy that is "good enough" without requiring excessive computation time or specialized hardware. This balance is often called the sweet spot. In some applications, large computational efforts are justified.

# %% [markdown]
# ## Question 4.7
#
# Perform the same type of sensitivity analysis as in the last question, but this time plot the true percent relative error at t = 50 hrs (yes- fifty!) on the y-axis instead.

# %%
# YOUR CODE HERE
# Calculate the numerical solution at 100 different h values
# While calculating, store the value of each numerical solution at t=50 hours
# Compare the value of the numerical solutions to the analytical solution at t=50 hours.
# Plot true percent relative error on the y axis, and h on the x axis.
# Label your axes

# %% [markdown]
# ## Question 4.8
#
# Are the errors larger or smaller at t=50 hours compared to t=0.5 hours? Why?
#
# *Write your answer here*
